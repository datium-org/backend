# %%
from db import Postgres, SchemaManager

db = Postgres(dbname="datium", user="alialh", password="", host="localhost")
db.connect()

# %%
# Create schema if it doesn't exist
schema_name = "test"
db.execute_query(f'CREATE SCHEMA IF NOT EXISTS {schema_name};')

# %%
from data_hierarchy import FileSystemManager

# %%
# Initialize the file system manager
fs_manager = FileSystemManager(schema_name, db)
# Out:
# folders
# ['"folder_id" UUID PRIMARY KEY DEFAULT uuid_generate_v4()', '"name" VARCHAR(255) NOT NULL', '"created_at" TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP', '"updated_at" TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP']
# CREATE TABLE IF NOT EXISTS "test"."folders" ("folder_id" UUID PRIMARY KEY DEFAULT uuid_generate_v4(), "name" VARCHAR(255) NOT NULL, "created_at" TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP, "updated_at" TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP)
# folder_closure
# ['"ancestor_id" UUID', '"descendant_id" UUID', '"depth" INTEGER NOT NULL', 'FOREIGN KEY (ancestor_id) REFERENCES test.folders(folder_id)', 'FOREIGN KEY (descendant_id) REFERENCES test.folders(folder_id)', 'PRIMARY KEY (ancestor_id, descendant_id)']
# ...

# %%
# Create root folder
root_id = fs_manager.create_folder('Business')

# Create subfolders
marketing_id = fs_manager.create_folder('Marketing', root_id)
finances_id = fs_manager.create_folder('Finances', root_id)

# %%
fs_manager.print_tree()
# Out:
# 📁 File System Tree:
# 📁 Business/
#     📁 Finances/
#     📁 Marketing/
