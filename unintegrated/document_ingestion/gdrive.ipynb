# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from pydrive.files import GoogleDriveFile


gauth = GoogleAuth()
gauth.LocalWebserverAuth(host_name="localhost", port_numbers=[8080])

drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=102588746491-gfn1p4gtrkmm6gc3nfeq504ongq3hc7i.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
def get_file(file: GoogleDriveFile):
  ext = file["fileExtension"]
  size = file["fileSize"]
  created_date = file["createdDate"]
  modified_date = file["modifiedDate"]
  last_viewed_by_me = file["lastViewedByMeDate"]

  print(f"

# %%
def get_file_by_id(id: str):
  file = drive.CreateFile({'id': id})
  return get_file(file)

def get_file_by_title(title: str):
  file = drive.CreateFile({'title': title})
  return get_file(file)

# %%
file1 = drive.CreateFile({'title': 'TestingUpload.txt'})
file1.SetContentString('Hello')
file1.Upload() # Files.insert()

# %%
file1['title'] = 'HelloWorld.txt'  # Change title of the file
file1.Upload() # Files.patch()

# %%
file3 = drive.CreateFile({'id': "1NX_gpOdsB78zqfPuljCFWwunZnWD38o9"})
print('Downloading file %s from Google Drive' % file3['title']) # 'hello.png'
# file3.GetContentFile('world.pdf')  # Save Drive file as a local file

for key, value in file3.items():
  print(f"{key}: {value}")
# Out:
# ...
# id: 1wdjvRMahHxyQPrGJoPAT20WPYmofLguk
# kind: drive#file
# userPermission: {'id': 'me', 'type': 'user', 'role': 'owner', 'kind': 'drive#permission', 'selfLink': 'https://www.googleapis.com/drive/v2/files/1wdjvRMahHxyQPrGJoPAT20WPYmofLguk/permissions/me', 'etag': '"M3EIJaqxwqyjCdAsBBwaIvgBBt8"', 'pendingOwner': False}
# fileExtension: pdf
# md5Checksum: 0bd1e7e0be0c33b566d57818d0f3e494
# selfLink: https://www.googleapis.com/drive/v2/files/1wdjvRMahHxyQPrGJoPAT20WPYmofLguk
# ownerNames: ['Ali A']
# lastModifyingUserName: Ali A
# editable: True
# writersCanShare: True
# downloadUrl: https://www.googleapis.com/drive/v2/files/1wdjvRMahHxyQPrGJoPAT20WPYmofLguk?alt=media&source=downloadUrl
# mimeType: application/pdf
# ...

# %%
# Paginate file lists by specifying number of max results
for file_list in drive.ListFile({'maxResults': 10}):
  print ('Received %s files from Files.list()' % len(file_list)) # <= 10
  for file1 in file_list:
    print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# Received 10 files from Files.list()
# title: Interview Question Bank, id: 1yBlP1CHDUH5gxp0wspMzOOMV9iYvjfRQ-JJDe8w0coI
# title: Inlab3_G02.docx, id: 1-3lP77vfHwh15xWS6U2s-7K3Qr2nQslO
# title: Ali_s_Resume_27.pdf, id: 1NX_gpOdsB78zqfPuljCFWwunZnWD38o9
# title: Waterloo Co-op Salaries + Blacklist v2, id: 1OEDRTAalRsyD1iAO5fkp_8HUJUxbYTavotHhwX0AwBU
# title: Ontario Universities Applicants 2021-2024, id: 1E_gAVTyeNHIYRgnzR_D7gPsbLoZDTXk59saUYPcLV3Q
# title: HelloWorld.txt, id: 1B8kqt_Mzt7UyyDq1RNcggyYRrNeuUzF0
# title: May 2021 IB grade boundaries sharing, id: 1mi_yqKN-0IYtLO5tFX6X7fQHwyySQIylt09wOCEDJdM
# title: (The Morgan Kaufmann Series in Computer Architecture and Design) David A. Patterson, John L. Hennessy - Computer Organization and Design_ The Hardware Software Interface [RISC-V Edition]-Morgan Kaufma.pdf, id: 1iMKc_MR7VOkaZxY-czN_xdwsjzX4vQjE
# title: Sahil-Kale-Resume, id: 1Gq1Xwg6jn_4MqMf4I2COhxDlqohBDNBJxANxLWufTuY
# ...
