# %%
from database.chroma import ChromaDB
import requests

# %%
files = {'file': open('poc/blob/test.json', 'rb')}

r = requests.post("http://127.0.0.1:8000/uploadfile", files=files)
r.text
# Out:
# '{"filename":"test.json"}'
